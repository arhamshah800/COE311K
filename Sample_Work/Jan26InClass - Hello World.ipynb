# %% [markdown]
# Hello Python! This is my very first notebook

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Any String!")
# Out:
# Any String!

# %%
print(5)
# Out:
# 5

# %%
print(5+10)
# Out:
# 15

# %%
print(True)
# Out:
# True

# %%
print(1.41)
# Out:
# 1.41

# %%
print("Hello Class!")
print("Tacc's awesome")
print("Indoctrination, yay!")
# Out:
# Hello Class!
# Tacc's awesome
# Indoctrination, yay!

# %%
2+5
# Out:
# 7

# %%
name = "Charlie"
NAME = "Alex"

# %%
print(name)
# Out:
# Charlie

# %%
print(NAME)
# Out:
# Alex

# %%
num1 = 5

# %%
1num = 7
# Out:
#   File "<ipython-input-16-010229339cf8>", line 1
#     1num = 7
#      ^
# SyntaxError: invalid syntax

# %%
num2 = 7

# %%
a = "Hello"
b = True

# %%
type(b)
# Out:
# bool

# %%
type(num2)
# Out:
# int

# %%
a = 2
b = 3

# %%
print(a>b)
# Out:
# False

# %%
print(b>a)
# Out:
# True

# %%
print(b==a)
# Out:
# False

# %%
import numpy as np
from numpy.random import default_rng

# %%
rng = default_rng()
y = rng.random(1000)

# %%
print(y)
# Out:
# [7.16555629e-01 8.82265608e-01 7.95380695e-01 6.19731512e-01
#  6.68428681e-01 3.05762910e-01 2.88088652e-01 6.28266470e-01
#  9.25436719e-01 9.56233210e-01 6.69512595e-01 1.95734916e-01
#  2.67613782e-01 3.06558579e-01 7.11477206e-02 3.45209777e-01
#  3.88044580e-01 6.30842149e-01 7.19191648e-01 5.83603358e-01
#  8.92426075e-01 8.26898722e-02 3.52757509e-01 2.86512421e-01
#  1.69098694e-01 3.27473038e-01 5.58896454e-01 3.51888368e-01
#  6.46726410e-01 4.31536526e-01 7.77634862e-01 5.72431107e-01
#  5.87647112e-01 4.68018580e-01 7.86846428e-01 2.21418464e-01
#  6.76289971e-02 4.75982314e-01 9.15301118e-01 5.46641308e-01
#  4.80338022e-02 1.11595436e-01 7.47321173e-01 4.61030107e-01
#  5.95735024e-01 5.63701304e-01 9.82868454e-04 4.77933095e-01
#  9.89753313e-01 5.43765883e-01 6.70323995e-01 2.61918977e-02
#  8.18643711e-01 2.00978964e-01 1.54301277e-01 5.60059183e-02
#  2.85193304e-01 8.22960797e-01 9.74932848e-01 8.19134420e-01
# ...

# %%
import math

# %%
sum = 0
for i in range(1,1000):
    value = rng.uniform(-1,1)
    value2 = rng.uniform(-1,1)
    if(sqrt(value**2+value2**2)<= 1):
        sum += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-de1eb45ff776> in <module>
#       3     value = rng.uniform(-1,1)
#       4     value2 = rng.uniform(-1,1)
# ----> 5     if(sqrt(value**2+value2**2)<= 1):
#       6         sum += 1
#
# NameError: name 'sqrt' is not defined

# %%
sum = 0
for i in range(1,1000):
    value = rng.uniform(-1,1)
    value2 = rng.uniform(-1,1)
    if(math.sqrt(value**2+value2**2)<= 1):
        sum += 1

# %%
print sum
# Out:
#   File "<ipython-input-34-11e472895756>", line 1
#     print sum
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(sum)?

# %%
print(sum)
# Out:
# 794

# %%
pi = 4*(sum/1000)

# %%
print(pi)
# Out:
# 3.176
