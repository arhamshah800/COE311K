# %%
import numpy as np
import time

# %%
def jacobi(A, b, tol=1e-6, max_iter=1000):
    n = len(A)
    x = np.zeros(n)
    x_new = np.zeros(n)
    
    start_time = time.perf_counter()
    for it in range(max_iter):
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if i != j)
            x_new[i] = (b[i] - s) / A[i][i]
            
      
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            end_time = time.perf_counter()
            return x_new, it + 1, end_time - start_time
            
    
        if np.any(np.isnan(x_new)) or np.any(np.isinf(x_new)) or np.max(np.abs(x_new)) > 1e10:
             return None, it + 1, time.perf_counter() - start_time
             
        x[:] = x_new
        
    end_time = time.perf_counter()
    return None, max_iter, end_time - start_time

# %%
def gauss_seidel(A, b, tol=1e-6, max_iter=1000):
    n = len(A)
    x = np.zeros(n)
    
    start_time = time.perf_counter()
    for it in range(max_iter):
        x_old = x.copy()
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if i != j)
            x[i] = (b[i] - s) / A[i][i]
            
        if np.linalg.norm(x - x_old, ord=np.inf) < tol:
            end_time = time.perf_counter()
            return x, it + 1, end_time - start_time
            
        if np.any(np.isnan(x)) or np.any(np.isinf(x)) or np.max(np.abs(x)) > 1e10:
             return None, it + 1, time.perf_counter() - start_time
             
    end_time = time.perf_counter()
    return None, max_iter, end_time - start_time

# %%
A = np.array([

[0.582745, 0.48 , 0.10 , 0.  , 0.  ],
[0.48 , 1.044129, 0.46 , 0.10 , 0.  ],
[0.10 , 0.46 , 1.10431 , 0.44 , 0.10 ],
[0.  , 0.10 , 0.44 , 0.963889, 0.42 ],
[0.  , 0.  , 0.10 , 0.42 , 0.522565]], dtype=float)

b = np.array([1.162745, 2.084129, 2.20431 , 1.923889, 1.042565], dtype=float)
x_jacobi, iter_jacobi, time_jacobi = jacobi(A,b)
print(f"Jacobi: \n  Iterations: {iter_jacobi}\n  Time: {time_jacobi:.6f} seconds\n  Result: {x_jacobi}")

x_gs, iter_gs, time_gs = gauss_seidel(A,b)
print(f"Gauss-Seidel: \n  Iterations: {iter_gs}\n  Time: {time_gs:.6f} seconds\n  Result: {x_gs}\n")
# Out:
# Jacobi:
#   Iterations: 1000
#   Time: 0.067820 seconds
#   Result: None
# Gauss-Seidel:
#   Iterations: 21
#   Time: 0.002986 seconds
#   Result: [0.99999926 1.00000045 0.99999989 0.99999997 1.00000005]

# %%
A = np.array([[1, 1], [1, 1.0001]])
b = np.array([1, 1])
x_jacobi, iter_jacobi, time_jacobi = jacobi(A,b)
print(f"Jacobi: \n  Iterations: {iter_jacobi}\n  Time: {time_jacobi:.6f} seconds\n  Result: {x_jacobi}")

x_gs, iter_gs, time_gs = gauss_seidel(A,b)
print(f"Gauss-Seidel: \n  Iterations: {iter_gs}\n  Time: {time_gs:.6f} seconds\n  Result: {x_gs}\n")
# Out:
# Jacobi:
#   Iterations: 1000
#   Time: 0.068437 seconds
#   Result: None
# Gauss-Seidel:
#   Iterations: 2
#   Time: 0.000150 seconds
#   Result: [1. 0.]

# %%
A = np.array([[1, 1], [1, 1.0001]])
b = np.array([1, 1.0001])
x_jacobi, iter_jacobi, time_jacobi = jacobi(A,b)
print(f"Jacobi: \n  Iterations: {iter_jacobi}\n  Time: {time_jacobi:.6f} seconds\n  Result: {x_jacobi}")

x_gs, iter_gs, time_gs = gauss_seidel(A,b)
print(f"Gauss-Seidel: \n  Iterations: {iter_gs}\n  Time: {time_gs:.6f} seconds\n  Result: {x_gs}\n")
# Out:
# Jacobi:
#   Iterations: 1000
#   Time: 0.055226 seconds
#   Result: None
# Gauss-Seidel:
#   Iterations: 1000
#   Time: 0.044442 seconds
#   Result: None
