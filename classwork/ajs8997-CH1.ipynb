# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# %%
x = np.linspace(0, 2 * np.pi, 50)

# %%
plt.subplot(2, 2, 1) # (row, column, active area)
plt.title('Random Color Graph') # Add a graph title.
x = np.random.rand(1000)
y = np.random.rand(1000)
size = np.random.rand(1000) * 50
color = np.random.rand(1000)
plt.scatter(x, y, size, color)
plt.colorbar()
plt.subplot(2, 2, 2)
plt.title('Scatter Plot') # Add a graph title.
x = np.linspace(0, 2 * np.pi, 50)
plt.scatter(x,np.cos(x))
plt.subplot(2, 2, 3)
plt.title('Normal Line') # Add a graph title.
plt.plot(x, np.sin(x))
plt.subplot(2, 2, 4)
plt.title('Bar Graph') # Add a graph title.
y = np.cos(x)
plt.bar(x,y)
plt.show()
