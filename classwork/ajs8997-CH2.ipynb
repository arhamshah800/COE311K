# %%
x = 2025

# %%
if x == 0:
    print("0")
binary_string = ""
while(x > 0):
    remainder = x%2
    binary_string = str(remainder) + binary_string
    x = x//2
    
print(binary_string)
# Out:
# 11111101001

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-abde155436af> in <module>
# ----> 1 remainders = decimal_to_binary(x)
#       2 print("Decimal: " + x)
#       3 print("Binary: " + remainders)
#
# <ipython-input-8-a7f9174ce912> in decimal_to_binary(x)
#       1 def decimal_to_binary(x):
#       2     remainders = []
# ----> 3     while x > 0:
#       4         remainder = x % 2
#       5         remainders.append(str(remainder))
#
# TypeError: '>' not supported between instances of 'str' and 'int'
